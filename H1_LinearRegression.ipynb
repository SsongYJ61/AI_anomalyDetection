# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:/Users/thddu/Desktop/데이터분석/진도대교분석/AI_anomalyDetection/data.csv", index_col = 0)
data.head()
# Out:
#        X   ind                    X.Time   ACC001_X   ACC001_Y  ACC001_Z  \
# 1   2029  2029  2018-01-02 09:38:00.0000  40.805119  25.504034  0.416799
# 7   2069  2069  2018-01-02 10:18:00.0000  40.827409  25.699538  0.758546
# 8   2091  2091  2018-01-02 10:40:00.0000  40.807949  25.851085  0.664547
# 15  2146  2146  2018-01-02 11:35:00.0000  40.980717  26.277307  1.573698
# 16  2151  2151  2018-01-02 11:40:00.0000  40.993807  26.313338  1.639161
#
#       ACC002_Z     ACC003_Z      CAC001      CAC002  ...  WGT002_S  WGT002_V  \
# 1   974.861377  1003.282507  712.910132  707.205802  ...  1.813764  0.289230
# 7   974.872434  1003.569013  712.738905  706.851693  ...  1.606156  0.312017
# 8   974.777937  1003.794401  712.730147  706.634184  ...  0.955877  0.169726
# 15  974.768914  1004.406324  712.621695  706.231516  ...  2.585505  0.166486
# 16  974.710911  1004.481729  712.663076  706.231409  ...  1.925782  0.316285
#
#     WVR001_HDR  WVR001_HSP  WVR001_PDR  WVR001_PSP  WVR002_HDR  WVR002_HSP  \
# 1     7.401429    0.424711  116.731682    3.260048   89.110220   60.459179
# 7    14.887839    0.439992  147.398011    1.670779   89.241007   60.369046
# 8     9.712352    0.134816  198.366212    0.827321   89.370690   60.502694
# 15   16.055534    0.734244  296.837162    2.585418   88.674855   60.469280
# 16   10.667167    0.430964  280.470441    2.179158   88.331297   60.458463
#
#     WVR002_PDR  WVR002_PSP
# 1   272.565559    0.995250
# 7   261.912444    0.857520
# 8   280.931183    0.696128
# 15   93.611917    1.421831
# 16   98.351081    1.768940
#
# [5 rows x 108 columns]

# %%
data_drop_col = ['X', 'ind']

# data삭제
data.drop(data_drop_col, axis = 1, inplace=True)

# %%
data.rename(columns = {"X.Time" : 'datetime'}, inplace=True)

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
print(data['datetime'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ## 트리모델로 연관성 파악
